# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Seaborn stilini ayarla
sns.set(style="whitegrid")

# %%
dosya_yolu = 'All_Orders_Ürün_İsimleri.csv'
df = pd.read_csv(dosya_yolu)

# Tüm sütunları görüntülemek için pandas ayarlarını değiştir
pd.set_option('display.max_columns', None)

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             order_id purchase_date  \
# 0             0           0  403-3538797-3315514    30/05/2024
# 1             1          16  407-1529181-3128329    22/05/2024
# 2             2          48  402-0925298-6082759    12/05/2024
# 3             3          65  171-6046087-3781929    04/05/2024
# 4             4          69  408-0925601-9533151    03/05/2024
#
#   last_updated_date order_status fulfillment sales_channel ship_service_level  \
# 0        30/05/2024      Pending      Amazon        Fransa           Standard
# 1        30/05/2024      Pending      Amazon        Fransa           Standard
# 2        13/05/2024      Shipped      Amazon        Fransa           Standard
# 3        13/05/2024      Shipped      Amazon        Fransa           Standard
# 4        06/05/2024      Shipped      Amazon        Fransa          Expedited
#
#          asin item_status  quantity currency  item_price  item_tax  \
# ...

# %%
sütun_isimleri = df.columns.tolist()
print("Sütun İsimleri:\n", sütun_isimleri)
# Out:
# Sütun İsimleri:
#  ['Unnamed: 0.1', 'Unnamed: 0', 'order_id', 'purchase_date', 'last_updated_date', 'order_status', 'fulfillment', 'sales_channel', 'ship_service_level', 'asin', 'item_status', 'quantity', 'currency', 'item_price', 'item_tax', 'ship_city', 'ship_country', 'business_order', 'amazon_invoiced', 'vat_exclusive_item_price', 'vat_shipping_price', 'product', 'sentetik_maliyet', 'sentetik_maliyet(€)', 'item_price(€)', 'vat_exclusive_item_price(€)', 'item_tax(€)', 'vat_exclusive_shipping_price(€)', 'Product Name', 'Categori', 'totall_saless(€)']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123772 entries, 0 to 123771
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Unnamed: 0.1                     123772 non-null  int64
#  1   Unnamed: 0                       123772 non-null  int64
#  2   order_id                         123772 non-null  object
#  3   purchase_date                    123772 non-null  object
#  4   last_updated_date                123772 non-null  object
#  5   order_status                     123772 non-null  object
#  6   fulfillment                      123772 non-null  object
#  7   sales_channel                    123772 non-null  object
#  8   ship_service_level               123772 non-null  object
#  9   asin                             123772 non-null  object
#  10  item_status                      123772 non-null  object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0.1     Unnamed: 0       quantity     item_price  \
# count  123772.000000  123772.000000  123772.000000  123772.000000
# mean    61885.500000   61899.253523       1.187660      13.086098
# std     35730.043096   35739.480020       0.902124      17.087140
# min         0.000000       0.000000       0.000000       0.000000
# 25%     30942.750000   30947.750000       1.000000       5.980000
# 50%     61885.500000   61898.500000       1.000000       9.890000
# 75%     92828.250000   92850.250000       1.000000      15.890000
# max    123771.000000  123801.000000      40.000000    1062.250000
#
#             item_tax  vat_exclusive_item_price  vat_shipping_price  \
# count  123772.000000             123772.000000       123772.000000
# mean        1.383471                 11.339020            0.267936
# std         2.010422                 15.544418            1.224028
# min         0.120000                  0.000000            0.000000
# ...

# %%
eksik_degerler = df.isnull().sum()
print("Her sütundaki eksik değerler:\n", eksik_degerler)
# Out:
# Her sütundaki eksik değerler:
#  Unnamed: 0.1                         0
# Unnamed: 0                           0
# order_id                             0
# purchase_date                        0
# last_updated_date                    0
# order_status                         0
# fulfillment                          0
# sales_channel                        0
# ship_service_level                   0
# asin                                 0
# item_status                          0
# quantity                             0
# currency                             0
# item_price                           0
# item_tax                             0
# ship_city                            0
# ship_country                         0
# business_order                       0
# amazon_invoiced                      0
# vat_exclusive_item_price             0
# vat_shipping_price                   0
# product                              0
# sentetik_maliyet                     0
# ...

# %%
en_yaygin_item_status = df['item_status'].mode()[0]
df['item_status'].fillna(en_yaygin_item_status, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 en_yaygin_item_status = df['item_status'].mode()[0]
#       2 df['item_status'].fillna(en_yaygin_item_status, inplace=True)
#
# NameError: name 'df' is not defined

# %%
en_yaygin_ship_city = df['ship_city'].mode()[0]
df['ship_city'].fillna(en_yaygin_ship_city, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 en_yaygin_ship_city = df['ship_city'].mode()[0]
#       2 df['ship_city'].fillna(en_yaygin_ship_city, inplace=True)
#
# NameError: name 'df' is not defined
